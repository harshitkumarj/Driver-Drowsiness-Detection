# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#PROBLEM-STATEMENT" data-toc-modified-id="PROBLEM-STATEMENT-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>PROBLEM STATEMENT</a></span></li><li><span><a href="#OVERVIEW" data-toc-modified-id="OVERVIEW-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>OVERVIEW</a></span></li><li><span><a href="#DATASET" data-toc-modified-id="DATASET-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>DATASET</a></span></li><li><span><a href="#FEATURE-EXTRACTION" data-toc-modified-id="FEATURE-EXTRACTION-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>FEATURE EXTRACTION</a></span></li><li><span><a href="#IMPORTING-THE-LIBRARIES" data-toc-modified-id="IMPORTING-THE-LIBRARIES-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>IMPORTING THE LIBRARIES</a></span></li><li><span><a href="#IMPORTING-THE-DATASET" data-toc-modified-id="IMPORTING-THE-DATASET-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>IMPORTING THE DATASET</a></span><ul class="toc-item"><li><span><a href="#Normalization-of-the-dataset" data-toc-modified-id="Normalization-of-the-dataset-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Normalization of the dataset</a></span></li></ul></li><li><span><a href="#IMPORTING-THE-MAIN-DATASET" data-toc-modified-id="IMPORTING-THE-MAIN-DATASET-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>IMPORTING THE MAIN DATASET</a></span></li><li><span><a href="#HISTOGRAMS" data-toc-modified-id="HISTOGRAMS-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>HISTOGRAMS</a></span></li><li><span><a href="#MULTICOLLINEARITY-OF-FEATURES" data-toc-modified-id="MULTICOLLINEARITY-OF-FEATURES-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>MULTICOLLINEARITY OF FEATURES</a></span><ul class="toc-item"><li><span><a href="#Pairplot" data-toc-modified-id="Pairplot-9.1"><span class="toc-item-num">9.1&nbsp;&nbsp;</span>Pairplot</a></span></li><li><span><a href="#Heatmap" data-toc-modified-id="Heatmap-9.2"><span class="toc-item-num">9.2&nbsp;&nbsp;</span>Heatmap</a></span></li></ul></li><li><span><a href="#MODEL-BUILDING" data-toc-modified-id="MODEL-BUILDING-10"><span class="toc-item-num">10&nbsp;&nbsp;</span>MODEL BUILDING</a></span><ul class="toc-item"><li><span><a href="#Hyperparameter-Tuning" data-toc-modified-id="Hyperparameter-Tuning-10.1"><span class="toc-item-num">10.1&nbsp;&nbsp;</span>Hyperparameter Tuning</a></span><ul class="toc-item"><li><span><a href="#Random-Forest-Classifier" data-toc-modified-id="Random-Forest-Classifier-10.1.1"><span class="toc-item-num">10.1.1&nbsp;&nbsp;</span>Random Forest Classifier</a></span></li><li><span><a href="#XGBoost-Classifier" data-toc-modified-id="XGBoost-Classifier-10.1.2"><span class="toc-item-num">10.1.2&nbsp;&nbsp;</span>XGBoost Classifier</a></span></li></ul></li></ul></li><li><span><a href="#ARTIFICIAL-NUERAL-NETWORK" data-toc-modified-id="ARTIFICIAL-NUERAL-NETWORK-11"><span class="toc-item-num">11&nbsp;&nbsp;</span>ARTIFICIAL NUERAL NETWORK</a></span><ul class="toc-item"><li><span><a href="#Predicting-the-Test-set-results" data-toc-modified-id="Predicting-the-Test-set-results-11.1"><span class="toc-item-num">11.1&nbsp;&nbsp;</span>Predicting the Test set results</a></span></li></ul></li><li><span><a href="#Viewing-the-Accuracy-Scores-of-the-best-fitted-models" data-toc-modified-id="Viewing-the-Accuracy-Scores-of-the-best-fitted-models-12"><span class="toc-item-num">12&nbsp;&nbsp;</span>Viewing the Accuracy Scores of the best fitted models</a></span></li></ul></div>

# %% [markdown]
# **<center>DRIVER DROWSINESS DETECTION** <br>**<center>By Harshit Kumar Jain, Priyanshu Jain, Naman Maheshwari**

# %% [markdown]
# # PROBLEM STATEMENT

# %% [markdown]
# The problem that our team is tackling is drowsiness detection. Drowsiness in the workplace, classroom, or on the road may lead to severe consequences and may even put the lives of many in danger. An effective solution that detects early stages of drowsiness may improve overall safety and human productivity with business applications in several domains.

# %% [markdown]
# # OVERVIEW

# %% [markdown]
# According to the National Highway Traffic Safety Administration, every year about 100,000 police-reported crashes involve drowsy driving. These crashes result in more than 1,550 fatalities and 71,000 injuries. <br>A study by the AAA Foundation for Traffic Safety estimated that 328,000 drowsy driving crashes occur annually. That's more than three times the police-reported number.
# <br>Beyond the human toll is the economic one. NHTSA estimates fatigue-related crashes resulting in injury or death cost society $109 billion annually, not including property damage.

# %% [markdown]
# # DATASET

# %% [markdown]
# For the training data we will use the real-life drowsiness video dataset provided by the University of Texas [(UTA)](https://sites.google.com/view/utarldd/home). These data are free to use for scientific or educational purposes and identities cannot be inferred based on these data only.<br>
# UTA dataset consists of 180 RGB videos of 60 unique participants. Each video is around 10 minutes long, and is labeled as belonging to one of two classes: alert (labeled as 0), low vigilant (labeled as 5) and drowsy (labeled as 10). The labels were provided by the participants themselves, based on their predominant state while recording each video.
#
# The data extraction part was done from the frames of videos, and the inputs received from the respondents/participants were recorded in the [totalwithrespondent.csv](https://github.com/harshitkumarj/Driver-Drowsiness-Detection/blob/main/totalwithrespondent.csv) file.

# %% [markdown]
# # FEATURE EXTRACTION

# %% [markdown]
# **Eye Aspect Ratio (EAR)**

# %% [markdown]
# EAR, as the name suggests, is the ratio of the length of the eyes to the width of the eyes. The length of the eyes is calculated by averaging over two distinct vertical lines across the eyes as illustrated in the figure below.

# %% [markdown]
# <IMG SRC="https://miro.medium.com/max/875/1*BlsrFzC8H6i3xv695Ja6vg.png">

# %% [markdown]
# **Mouth Aspect Ratio (MAR)**

# %% [markdown]
# Computationally similar to the EAR, the MAR, as you would expect, measures the ratio of the length of the mouth to the width of the mouth. Our hypothesis was that as an individual becomes drowsy, they are likely to yawn and lose control over their mouth, making their MAR to be higher than usual in this state.

# %% [markdown]
# <IMG SRC="https://miro.medium.com/max/875/1*J92GDZOs589HUbXB7Flo1g.png">

# %% [markdown]
# **Circularity**

# %% [markdown]
# Circularity is a measure complementary to EAR, but it places a greater emphasis on the pupil instead of the entire eye.<br>
# For example, someone who has their eyes half-open or almost closed will have a much lower pupil circularity value versus someone who has their eyes fully open due to the squared term in the denominator. Similar to the EAR, the expectation was that when an individual is drowsy, their pupil circularity is likely to decline.

# %% [markdown]
# <IMG SRC="https://miro.medium.com/max/875/1*EMfSBDCen-Pj_n3UpUgbuQ.png">

# %% [markdown]
# **Mouth aspect ratio over Eye aspect ratio (MOE)**

# %% [markdown]
# Finally, we decided to add MOE as another feature. MOE is simply the ratio of the MAR to the EAR. The benefit of using this feature is that EAR and MAR are expected to move in opposite directions if the state of the individual changes. As opposed to both EAR and MAR, MOE as a measure will be more responsive to these changes as it will capture the subtle changes in both EAR and MAR and will exaggerate the changes as the denominator and numerator move in opposite directions. Because the MOE takes MAR as the numerator and EAR as the denominator, our theory was that as the individual gets drowsy, the MOE will increase.

# %% [markdown]
# <IMG SRC="https://miro.medium.com/max/418/1*zhssq_xd9MG2C9t-hGSiPg.png">

# %% [markdown]
# # IMPORTING THE LIBRARIES

# %%
from sklearn.base import BaseEstimator, TransformerMixin
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_curve, roc_auc_score, f1_score
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LogisticRegression
from sklearn.neural_network import MLPClassifier
from sklearn.naive_bayes import BernoulliNB
from sklearn.tree import DecisionTreeClassifier
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn import metrics
import warnings

# %% [markdown]
# # IMPORTING THE DATASET

# %%
df = pd.read_csv('totalwithrespondent.csv')

# %%
df
# Out:
#         Y       MOE  Participant       EAR       MAR  Circularity
# 0     0.0  2.534145          1.0  0.312688  0.792397     0.432896
# 1     0.0  2.379947          1.0  0.321940  0.766199     0.486923
# 2     0.0  2.078550          1.0  0.331216  0.688449     0.456029
# 3     0.0  2.509767          1.0  0.309246  0.776136     0.452655
# 4     0.0  3.586821          1.0  0.204691  0.734189     0.361123
# ...   ...       ...          ...       ...       ...          ...
# 8635  1.0  4.791645         60.0  0.213104  1.021117     0.367879
# 8636  1.0  4.072009         60.0  0.244625  0.996117     0.445070
# 8637  1.0  3.644583         60.0  0.286575  1.044448     0.425488
# 8638  1.0  3.840868         60.0  0.265593  1.020106     0.414632
# 8639  1.0  3.771236         60.0  0.270172  1.018881     0.426082
#
# [8640 rows x 6 columns]

# %%
#Getting the information of the imported dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8640 entries, 0 to 8639
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Y            8640 non-null   float64
#  1   MOE          8640 non-null   float64
#  2   Participant  8640 non-null   float64
#  3   EAR          8640 non-null   float64
#  4   MAR          8640 non-null   float64
#  5   Circularity  8640 non-null   float64
# dtypes: float64(6)
# memory usage: 405.1 KB

# %% [markdown]
# ## Normalization of the dataset

# %%
#Separating the rows which are "Alert" only
df_alert = df[df["Y"]==0]

# %%
#Creating separate dataframes for each respondent's first, second and third "Alert" frame
df_alert_1 = df_alert.iloc[0::240, :]
df_alert_2 = df_alert.iloc[1::240, :]
df_alert_3 = df_alert.iloc[2::240, :]

# %%
#Merging them into one dataframe
alert_first3 = [df_alert_1,df_alert_2,df_alert_3]
df_alert_first3 = pd.concat(alert_first3)
df_alert_first3 = df_alert_first3.sort_index()

# %%
#Based on the first 3 "Alert" frames, calculating participant-wise mean and std for each feature
df_means = df_alert_first3.groupby("Participant")["EAR","MAR","Circularity","MOE"].mean()
df_std = df_alert_first3.groupby("Participant")["EAR","MAR","Circularity","MOE"].std()
# Out:
# <ipython-input-8-c854e9d038ed>:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df_means = df_alert_first3.groupby("Participant")["EAR","MAR","Circularity","MOE"].mean()
# <ipython-input-8-c854e9d038ed>:3: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df_std = df_alert_first3.groupby("Participant")["EAR","MAR","Circularity","MOE"].std()

# %%
#Functions for mean and std for each feature
def mean_EAR(participant):
    return df_means.loc[participant]["EAR"]

def mean_MAR(participant):
    return df_means.loc[participant]["MAR"]

def mean_Circularity(participant):
    return df_means.loc[participant]["Circularity"]

def mean_MOE(participant):
    return df_means.loc[participant]["MOE"]

def std_EAR(participant):
    return df_std.loc[participant]["EAR"]

def std_MAR(participant):
    return df_std.loc[participant]["MAR"]

def std_Circularity(participant):
    return df_std.loc[participant]["Circularity"]

def std_MOE(participant):
    return df_std.loc[participant]["MOE"]

# %%
#Adding participant-wise mean and std for each feature to each row in the original dataframe
df["EAR_mean"] = df["Participant"].apply(mean_EAR)
df["MAR_mean"] = df["Participant"].apply(mean_MAR)
df["Circularity_mean"] = df["Participant"].apply(mean_Circularity)
df["MOE_mean"] = df["Participant"].apply(mean_MOE)

df["EAR_std"] = df["Participant"].apply(std_EAR)
df["MAR_std"] = df["Participant"].apply(std_MAR)
df["Circularity_std"] = df["Participant"].apply(std_Circularity)
df["MOE_std"] = df["Participant"].apply(std_MOE)

# %%
#Calculating normalised features for each row in the original dataframe
df["EAR_N"] = (df["EAR"]-df["EAR_mean"])/ df["EAR_std"]
df["MAR_N"] = (df["MAR"]-df["MAR_mean"])/ df["MAR_std"]
df["Circularity_N"] = (df["Circularity"]-df["Circularity_mean"])/ df["Circularity_std"]
df["MOE_N"] = (df["MOE"]-df["MOE_mean"])/ df["MOE_std"]

# %%
#Saving the file to a CSV with all the information
df.to_csv('totalwithallinfo.csv',index=False)

# %%
#Saving the file to a CSV with the main information
df_main = df.drop(["EAR_mean","MAR_mean","Circularity_mean","MOE_mean","EAR_std","MAR_std","Circularity_std","MOE_std"],axis=1)
df_main.to_csv('totalwithmaininfo.csv',index=False)

# %% [markdown]
# # IMPORTING THE MAIN DATASET

# %%
df = pd.read_csv('totalwithmaininfo.csv',sep=',')

# %%
#Getting the information of the main dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8640 entries, 0 to 8639
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Y              8640 non-null   float64
#  1   MOE            8640 non-null   float64
#  2   Participant    8640 non-null   float64
#  3   EAR            8640 non-null   float64
#  4   MAR            8640 non-null   float64
#  5   Circularity    8640 non-null   float64
#  6   EAR_N          8640 non-null   float64
#  7   MAR_N          8640 non-null   float64
#  8   Circularity_N  8640 non-null   float64
#  9   MOE_N          8640 non-null   float64
# dtypes: float64(10)
# memory usage: 675.1 KB

# %%
#Printing the first 5 rows of the dataset
df.head()
# Out:
#      Y       MOE  Participant       EAR       MAR  Circularity      EAR_N  \
# 0  0.0  2.534145          1.0  0.312688  0.792397     0.432896  -0.999551
# 1  0.0  2.379947          1.0  0.321940  0.766199     0.486923  -0.000897
# 2  0.0  2.078550          1.0  0.331216  0.688449     0.456029   1.000448
# 3  0.0  2.509767          1.0  0.309246  0.776136     0.452655  -1.371052
# 4  0.0  3.586821          1.0  0.204691  0.734189     0.361123 -12.657205
#
#       MAR_N  Circularity_N     MOE_N
# 0  0.802437      -0.948848  0.877172
# 1  0.317858       1.044306  0.211742
# 2 -1.120295      -0.095458 -1.088914
# 3  0.501666      -0.219920  0.771970
# 4 -0.274242      -3.596686  5.419921

# %%
#Checking for null values in the dataset
df.isnull().sum()
# Out:
# Y                0
# MOE              0
# Participant      0
# EAR              0
# MAR              0
# Circularity      0
# EAR_N            0
# MAR_N            0
# Circularity_N    0
# MOE_N            0
# dtype: int64

# %%
#Counting the number of entries for each label
df['Y'].value_counts()
# Out:
# 1.0    4320
# 0.0    4320
# Name: Y, dtype: int64

# %% [markdown]
# # HISTOGRAMS

# %%
#Displaying histograms to view the distribution of every feature
fig, axes = plt.subplots(4, 2, figsize=(20,20))
sns.histplot(data=df['MOE'], ax=axes[0, 0],color='green')
sns.histplot(data=df['EAR'], ax=axes[0, 1],color='Blue')
sns.histplot(data=df['MAR'], ax=axes[1, 0],color='yellow')
sns.histplot(data=df['Circularity'], ax=axes[1, 1],color='gray')
sns.histplot(data=df['EAR_N'], ax=axes[2, 0],color='lightgreen')
sns.histplot(data=df['MAR_N'], ax=axes[2, 1],color='brown')
sns.histplot(data=df['Circularity_N'], ax=axes[3, 0],color='green')
sns.histplot(data=df['MOE_N'], ax=axes[3, 1],color='Blue')
plt.show()

# %% [markdown]
# # MULTICOLLINEARITY OF FEATURES

# %% [markdown]
# ## Pairplot

# %%
sns.pairplot(df,hue='Y')

# %% [markdown]
# ## Heatmap

# %%
#Creating a heatmap to display the collinearity between the features
fig = plt.figure(figsize = (15,12))
mask = np.triu(np.ones_like(df.corr(), dtype=bool))
sns.heatmap(df.corr(), mask=mask, vmax=0.5, center=0, square=True, linewidths=.5, annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # MODEL BUILDING

# %%
#Creating x for independent variables and y for the dependent variable
x=df.iloc[:,1:].values
y=df.iloc[:,0].values

# %%
#Splitting the dataset into train and test distribution with 80% in train and 20% in test
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.20, random_state=0)

# %%
print('Train size for label 0:',len(y_train[y_train==0]))
print('Train size for label 1:',len(y_train[y_train==1]))
print('Test size for label 0:',len(y_test[y_test==0]))
print('Test size for label 1:',len(y_test[y_test==1]))
# Out:
# Train size for label 0: 3458
# Train size for label 1: 3454
# Test size for label 0: 862
# Test size for label 1: 866

# %%
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import StratifiedKFold
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier
import xgboost as xgb

# %%
#Training various classification models on the dataset and determing the model with better accuracy
models = []
models.append(('LR', LogisticRegression(solver='liblinear', multi_class='ovr')))
models.append(('LDA', LinearDiscriminantAnalysis()))
models.append(('KNN', KNeighborsClassifier()))
models.append(('CART', DecisionTreeClassifier()))
models.append(('NB', GaussianNB()))
models.append(('RFC', RandomForestClassifier()))
models.append(('XGB', xgb.XGBClassifier(eval_metric = "error")))
# evaluate each model in turn
results = []
names = []
for name, model in models:
    kfold = StratifiedKFold(n_splits=10, random_state=1, shuffle=True)
    cv_results = cross_val_score(model, x_train, y_train, cv=kfold, scoring='accuracy')
    results.append(cv_results)
    names.append(name)
    print('%s: %f (%f)' % (name, cv_results.mean(), cv_results.std()))
# Out:
# LR: 0.772859 (0.020332)
# LDA: 0.759984 (0.018580)
# KNN: 0.857926 (0.015712)
# CART: 0.831888 (0.009021)
# NB: 0.705872 (0.012697)
# RFC: 0.873551 (0.010876)
# c:\users\thesurprisebox\appdata\local\programs\python\python38\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# XGB: 0.875432 (0.014396)

# %% [markdown]
# ## Hyperparameter Tuning

# %% [markdown]
# As per the accuracy score, RFC and XGB are the best fitted models on the dataset.<br>
# Therefore, we will perform Hyperparameter Tuning on both RFC and XGB to find out the best one.

# %% [markdown]
# ### Random Forest Classifier

# %%
#Initializing the parameters for hyperparameter tuning for RFC
n_estimators = [int(x) for x in np.linspace(start = 100, stop = 800, num = 8)]
max_depth = [int(x) for x in np.linspace(5, 25, num = 5)]
random_grid = {'n_estimators': n_estimators,'max_depth': max_depth,}

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
rf_random = RandomizedSearchCV(estimator = RandomForestClassifier(), param_distributions = random_grid,scoring='accuracy', n_iter = 100, cv = 5, verbose=2, random_state=0, n_jobs = -1)

# %%
#Fitting the parameters
rf_random.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 40 candidates, totalling 200 fits
# c:\users\thesurprisebox\appdata\local\programs\python\python38\lib\site-packages\sklearn\model_selection\_search.py:278: UserWarning: The total space of parameters 40 is smaller than n_iter=100. Running 40 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:   30.1s
# [Parallel(n_jobs=-1)]: Done 146 tasks      | elapsed:  4.6min
# [Parallel(n_jobs=-1)]: Done 200 out of 200 | elapsed:  6.9min finished
# RandomizedSearchCV(cv=5, estimator=RandomForestClassifier(), n_iter=100,
#                    n_jobs=-1,
#                    param_distributions={'max_depth': [5, 10, 15, 20, 25],
#                                         'n_estimators': [100, 200, 300, 400,
#                                                          500, 600, 700, 800]},
# ...

# %%
#Determining the best parameters
rf_random.best_params_
# Out:
# {'n_estimators': 100, 'max_depth': 25}

# %%
#Determining the best score obtained on fitting over the dataset
rf_random.best_score_
# Out:
# 0.87442031783503

# %%
#Making predictions on the test data
y_pred_rfc=rf_random.predict(x_test)

# %%
#Printing the confusion matrix and accuracy score for RFC
from sklearn.metrics import confusion_matrix, accuracy_score
cm = confusion_matrix(y_test, y_pred_rfc)
print(cm)
acc_rfc = accuracy_score(y_test, y_pred_rfc)
print(acc_rfc)
# Out:
# [[762 100]
#  [107 759]]
# 0.8802083333333334

# %% [markdown]
# ### XGBoost Classifier

# %%
#Initializing the parameters for hyperparameter tuning for XGBClassifier
learning_rate = ['0.05','0.1', '0.2','0.3','0.5','0.6']
n_estimators = [int(x) for x in np.linspace(start = 100, stop = 1200, num = 12)]
max_depth = [int(x) for x in np.linspace(5, 30, num = 6)]
random_grid = {'n_estimators': n_estimators, 'max_depth': max_depth, 'learning_rate': learning_rate}

# %%
xg_random = RandomizedSearchCV(estimator = xgb.XGBClassifier(), param_distributions = random_grid,scoring='accuracy', n_iter = 100, cv = 5, verbose=2, random_state=0, n_jobs = -1)

# %%
#Fitting the parameters
xg_random.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:  2.7min
# [Parallel(n_jobs=-1)]: Done 146 tasks      | elapsed: 11.3min
# [Parallel(n_jobs=-1)]: Done 349 tasks      | elapsed: 24.1min
# [Parallel(n_jobs=-1)]: Done 500 out of 500 | elapsed: 31.0min finished
# c:\users\thesurprisebox\appdata\local\programs\python\python38\lib\site-packages\xgboost\sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# ...

# %%
#Determining the best parameters
xg_random.best_params_
# Out:
# {'n_estimators': 700, 'max_depth': 5, 'learning_rate': '0.1'}

# %%
#Determining the best score obtained on fitting over the dataset
xg_random.best_score_
# Out:
# 0.8748552037193417

# %%
#Making predictions on the test data
y_pred_xgb=xg_random.predict(x_test)

# %%
#Printing the confusion matrix and accuracy score for XGB Classifier
from sklearn.metrics import confusion_matrix, accuracy_score
cm = confusion_matrix(y_test, y_pred_xgb)
print(cm)
acc_xgb = accuracy_score(y_test, y_pred_xgb)
print(acc_xgb)
# Out:
# [[756 106]
#  [113 753]]
# 0.8732638888888888

# %% [markdown]
# # ARTIFICIAL NUERAL NETWORK

# %%
import tensorflow as tf
tf.__version__
# Out:
# '2.3.1'

# %%
#Initializing the ANN
ann = tf.keras.models.Sequential()

# %%
#Adding the input layer and the first hidden layer
ann.add(tf.keras.layers.Dense(units=8, activation='relu'))

# %%
#Adding the second hidden layer
ann.add(tf.keras.layers.Dense(units=16, activation='relu'))

# %%
#Adding the third hidden layer
ann.add(tf.keras.layers.Dense(units=32, activation='relu'))

# %%
#Adding the output layer
ann.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# %%
#Compiling the ANN
#Using the Adam optimizer 
ann.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
#Fitting the ann model in the batch size of 32 and 50 epochs
ann.fit(x_train, y_train, batch_size = 32, epochs = 50)
# Out:
# Epoch 1/50
# 216/216 [==============================] - 0s 591us/step - loss: 0.6296 - accuracy: 0.6312
# Epoch 2/50
# 216/216 [==============================] - 0s 602us/step - loss: 0.5250 - accuracy: 0.7422
# Epoch 3/50
# 216/216 [==============================] - 0s 566us/step - loss: 0.4808 - accuracy: 0.7740
# Epoch 4/50
# 216/216 [==============================] - 0s 570us/step - loss: 0.4506 - accuracy: 0.7937
# Epoch 5/50
# 216/216 [==============================] - 0s 559us/step - loss: 0.4326 - accuracy: 0.8096
# Epoch 6/50
# 216/216 [==============================] - 0s 588us/step - loss: 0.4198 - accuracy: 0.8112
# Epoch 7/50
# 216/216 [==============================] - 0s 549us/step - loss: 0.4135 - accuracy: 0.8180
# Epoch 8/50
# 216/216 [==============================] - 0s 602us/step - loss: 0.4104 - accuracy: 0.8155
# Epoch 9/50
# 216/216 [==============================] - 0s 600us/step - loss: 0.4027 - accuracy: 0.8194
# Epoch 10/50
# ...

# %% [markdown]
# ## Predicting the Test set results

# %%
#Predicitng the test data
y_pred_ann = ann.predict(x_test)

# %%
#Converting the continuous values into discrete
y_pred_ann = (y_pred_ann > 0.5)

# %%
cm = confusion_matrix(y_test, y_pred_ann)
print(cm)
# Out:
# [[701 161]
#  [117 749]]

# %%
acc_ann = accuracy_score(y_test, y_pred_ann)
print(acc_ann)
# Out:
# 0.8391203703703703

# %% [markdown]
# # Viewing the Accuracy Scores of the best fitted models

# %%
accuracy_scores = {"Accuracy Score of RFC":acc_rfc,"Accuracy Score of XGB": acc_xgb,"Accuracy Score of ANN": acc_ann}

# %%
accuracy_scores
# Out:
# {'Accuracy Score of RFC': 0.8802083333333334,
#  'Accuracy Score of XGB': 0.8732638888888888,
#  'Accuracy Score of ANN': 0.8391203703703703}
